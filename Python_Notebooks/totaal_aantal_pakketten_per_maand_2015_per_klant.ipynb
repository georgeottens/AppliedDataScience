# %%
# Import packages
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import data
df = pd.read_csv('/datc/parcel/notebooks/data/postnl/20200904_sample.csv', index_col=0, parse_dates=[1])

# %%
# Manipulate data
df['maand'] = df['procesdag'].dt.month
new_df = df.where(df['procesdag'].dt.year == 2015).groupby([df['cust_id'], df['maand']]).agg(totaal_aantal_pakketten = ('aantal_pakketten', 'sum'), totaal_aantal_pakketten_volgende_dag = ('aantal_pakketten_volgende_dag', 'sum')).reset_index()

# %%
# Total number of packages per month 2015
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_1').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['maand'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'Maand',
    ylabel = 'Aantal pakketten',
    title = 'Totaal aantal pakketten per maand 2015 voor klant 1')
# Out:
# [Text(0, 0.5, 'Aantal pakketten'),
#  Text(0.5, 0, 'Maand'),
#  Text(0.5, 1.0, 'Totaal aantal pakketten per maand 2015 voor klant 1')]

# %%
# Total number of packages per month 2015
df_klant2 = new_df.where(new_df['cust_id'] == 'klant_2').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant2['maand'], df_klant2['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'Maand',
    ylabel = 'Aantal pakketten',
    title = 'Totaal aantal pakketten per maand 2015 voor klant 2')
# Out:
# [Text(0, 0.5, 'Aantal pakketten'),
#  Text(0.5, 0, 'Maand'),
#  Text(0.5, 1.0, 'Totaal aantal pakketten per maand 2015 voor klant 2')]

# %%
# Total number of packages per month 2015
df_klant3 = new_df.where(new_df['cust_id'] == 'klant_3').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant3['maand'], df_klant3['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'Maand',
    ylabel = 'Aantal pakketten',
    title = 'Totaal aantal pakketten per maand 2015 voor klant 3')
# Out:
# [Text(0, 0.5, 'Aantal pakketten'),
#  Text(0.5, 0, 'Maand'),
#  Text(0.5, 1.0, 'Totaal aantal pakketten per maand 2015 voor klant 3')]

# %%
# Total number of packages per month 2015
df_klant4 = new_df.where(new_df['cust_id'] == 'klant_4').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant4['maand'], df_klant4['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'Maand',
    ylabel = 'Aantal pakketten',
    title = 'Totaal aantal pakketten per maand 2015 voor klant 4')
# Out:
# [Text(0, 0.5, 'Aantal pakketten'),
#  Text(0.5, 0, 'Maand'),
#  Text(0.5, 1.0, 'Totaal aantal pakketten per maand 2015 voor klant 4')]

# %%
# Total number of packages per month 2015
df_klant5 = new_df.where(new_df['cust_id'] == 'klant_5').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant5['maand'], df_klant5['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'Maand',
    ylabel = 'Aantal pakketten',
    title = 'Totaal aantal pakketten per maand 2015 voor klant 5')
# Out:
# [Text(0, 0.5, 'Aantal pakketten'),
#  Text(0.5, 0, 'Maand'),
#  Text(0.5, 1.0, 'Totaal aantal pakketten per maand 2015 voor klant 5')]

# %%
# Total number of packages per month 2015
df_klant6 = new_df.where(new_df['cust_id'] == 'klant_6').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant6['maand'], df_klant6['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'Maand',
    ylabel = 'Aantal pakketten',
    title = 'Totaal aantal pakketten per maand 2015 voor klant 6')
# Out:
# [Text(0, 0.5, 'Aantal pakketten'),
#  Text(0.5, 0, 'Maand'),
#  Text(0.5, 1.0, 'Totaal aantal pakketten per maand 2015 voor klant 6')]
